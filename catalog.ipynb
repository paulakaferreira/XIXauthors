# %%
import pandas as pd

# %%
df = pd.read_csv('catalog.csv')
# Out:
# /tmp/ipykernel_17652/3006687684.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('catalog.csv')

# %%
df
# Out:
#        Text#  Type      Issued  \
# 0          1  Text  1971-12-01
# 1          2  Text  1972-12-01
# 2          3  Text  1973-11-01
# 3          4  Text  1973-11-01
# 4          5  Text  1975-12-01
# ...      ...   ...         ...
# 69658  69737  Text  2023-01-07
# 69659  69738  Text  2023-01-07
# 69660  69739  Text  2023-01-07
# 69661  69740  Text  2023-01-08
# 69662  90907  Text  2019-12-12
#
#                                                    Title Language  \
# 0      The Declaration of Independence of the United ...       en
# 1      The United States Bill of Rights\r\nThe Ten Or...       en
# 2                    John F. Kennedy's Inaugural Address       en
# 3      Lincoln's Gettysburg Address\r\nGiven November...       en
# 4                         The United States Constitution       en
# ...                                                  ...      ...
# 69658                           Papa's own girl: A novel       en
# ...
